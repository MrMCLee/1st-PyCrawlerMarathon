# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11098672311","type":"CreateEvent","actor":{"id":58440727,"login":"Makar-tester","display_login":"Makar-tester","gravatar_id":"","url":"https://api.github.com/users/Makar-tester","avatar_url":"https://avatars.githubusercontent.com/u/58440727?"},"repo":{"id":228418869,"name":"Makar-tester/lesson21","url":"https://api.github.com/repos/Makar-tester/lesson21"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-16T15:37:01Z"},{"id":"11098672295","type":"PushEvent","actor":{"id":20613899,"login":"Alleidun","display_login":"Alleidun","gravatar_id":"","url":"https://api.github.com/users/Alleidun","avatar_url":"https://avatars.githubusercontent.com/u/20613899?"},"repo":{"id":227195714,"name":"physicalcomputing101/physicalcomputing101.github.io","url":"https://api.github.com/repos/physicalcomputing101/physicalcomputing101.github.io"},"payload":{"push_id":4402625058,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"bd8d7c01302061d07e695c10980b40895a00cbfc","before":"5a3a9680eecc84eca98583ad7e41dce14c179d0e","commits":[{"sha":"bd8d7c01302061d07e695c10980b40895a00cbfc","author":{"email":"bwsj@create.aau.dk","name":"Walther Jensen"},"message":"- Changes to navbar","distinct":true,"url":"https://api.github.com/repos/physicalcomputing101/physicalcomputing101.github.io/commits/bd8d7c01302061d07e695c10980b40895a00cbfc"}]},"public":true,"created_at":"2019-12-16T15:37:01Z","org":{"id":58747613,"login":"physicalcomputing101","gravatar_id":"","url":"https://api.github.com/orgs/physicalcomputing101","avatar_url":"https://avatars.githubusercontent.com/u/58747613?"}},{"id":"11098672278","type":"PushEvent","actor":{"id":33645731,"login":"Katistic","display_login":"Katistic","gravatar_id":"","url":"https://api.github.com/users/Katistic","avatar_url":"https://avatars.githubusercontent.com/u/33645731?"},"repo":{"id":228392135,"name":"Katistic/Launchpyad","url":"https://api.github.com/repos/Katistic/Launchpyad"},"payload":{"push_id":4402625048,"size":3,"distinct_size":3,"ref":"refs/heads/master","head":"814ee59e93e6b9ee6f97bfce524e3619a1f49f0e","before":"798d3a184dfefb435ce8b1a1fd935b8c7bb472a2","commits":[{"sha":"2ca14361cf9d1250da4f3c8fde05d9a20628deaf","author":{"email":"33645731+Katistic@users.noreply.github.com","name":"Kat"},"message":"Update Mapper.py","distinct":true,"url":"https://api.github.com/repos/Katistic/Launchpyad/commits/2ca14361cf9d1250da4f3c8fde05d9a20628deaf"},{"sha":"afdde2afb2b95b6d118eea3db9e59ae404a4c962","author":{"email":"33645731+Katistic@users.noreply.github.com","name":"Kat"},"message":"Change device","distinct":true,"url":"https://api.github.com/repos/Katistic/Launchpyad/commits/afdde2afb2b95b6d118eea3db9e59ae404a4c962"},{"sha":"814ee59e93e6b9ee6f97bfce524e3619a1f49f0e","author":{"email":"33645731+Katistic@users.noreply.github.com","name":"Kat"},"message":"Update Mapper.py","distinct":true,"url":"https://api.github.com/repos/Katistic/Launchpyad/commits/814ee59e93e6b9ee6f97bfce524e3619a1f49f0e"}]},"public":true,"created_at":"2019-12-16T15:37:01Z"},{"id":"11098672309","type":"PullRequestEvent","actor":{"id":16877058,"login":"yaroslavNqualisystems","display_login":"yaroslavNqualisystems","gravatar_id":"","url":"https://api.github.com/users/yaroslavNqualisystems","avatar_url":"https://avatars.githubusercontent.com/u/16877058?"},"repo":{"id":221949883,"name":"QualiSystems/Shell-Explorer","url":"https://api.github.com/repos/QualiSystems/Shell-Explorer"},"payload":{"action":"closed","number":11,"pull_request":{"url":"https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11","id":353625870,"node_id":"MDExOlB1bGxSZXF1ZXN0MzUzNjI1ODcw","html_url":"https://github.com/QualiSystems/Shell-Explorer/pull/11","diff_url":"https://github.com/QualiSystems/Shell-Explorer/pull/11.diff","patch_url":"https://github.com/QualiSystems/Shell-Explorer/pull/11.patch","issue_url":"https://api.github.com/repos/QualiSystems/Shell-Explor ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11098672311',
#   'type': 'CreateEvent',
#   'actor': {'id': 58440727,
#    'login': 'Makar-tester',
#    'display_login': 'Makar-tester',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Makar-tester',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58440727?'},
#   'repo': {'id': 228418869,
#    'name': 'Makar-tester/lesson21',
#    'url': 'https://api.github.com/repos/Makar-tester/lesson21'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672295',
#   'type': 'PushEvent',
#   'actor': {'id': 20613899,
#    'login': 'Alleidun',
#    'display_login': 'Alleidun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alleidun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20613899?'},
#   'repo': {'id': 227195714,
#    'name': 'physicalcomputing101/physicalcomputing101.github.io',
#    'url': 'https://api.github.com/repos/physicalcomputing101/physicalcomputing101.github.io'},
#   'payload': {'push_id': 4402625058,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'bd8d7c01302061d07e695c10980b40895a00cbfc',
#    'before': '5a3a9680eecc84eca98583ad7e41dce14c179d0e',
#    'commits': [{'sha': 'bd8d7c01302061d07e695c10980b40895a00cbfc',
#      'author': {'email': 'bwsj@create.aau.dk', 'name': 'Walther Jensen'},
#      'message': '- Changes to navbar',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/physicalcomputing101/physicalcomputing101.github.io/commits/bd8d7c01302061d07e695c10980b40895a00cbfc'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 58747613,
#    'login': 'physicalcomputing101',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/physicalcomputing101',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58747613?'}},
#  {'id': '11098672278',
#   'type': 'PushEvent',
#   'actor': {'id': 33645731,
#    'login': 'Katistic',
#    'display_login': 'Katistic',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Katistic',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33645731?'},
#   'repo': {'id': 228392135,
#    'name': 'Katistic/Launchpyad',
#    'url': 'https://api.github.com/repos/Katistic/Launchpyad'},
#   'payload': {'push_id': 4402625048,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': '814ee59e93e6b9ee6f97bfce524e3619a1f49f0e',
#    'before': '798d3a184dfefb435ce8b1a1fd935b8c7bb472a2',
#    'commits': [{'sha': '2ca14361cf9d1250da4f3c8fde05d9a20628deaf',
#      'author': {'email': '33645731+Katistic@users.noreply.github.com',
#       'name': 'Kat'},
#      'message': 'Update Mapper.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Katistic/Launchpyad/commits/2ca14361cf9d1250da4f3c8fde05d9a20628deaf'},
#     {'sha': 'afdde2afb2b95b6d118eea3db9e59ae404a4c962',
#      'author': {'email': '33645731+Katistic@users.noreply.github.com',
#       'name': 'Kat'},
#      'message': 'Change device',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Katistic/Launchpyad/commits/afdde2afb2b95b6d118eea3db9e59ae404a4c962'},
#     {'sha': '814ee59e93e6b9ee6f97bfce524e3619a1f49f0e',
#      'author': {'email': '33645731+Katistic@users.noreply.github.com',
#       'name': 'Kat'},
#      'message': 'Update Mapper.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Katistic/Launchpyad/commits/814ee59e93e6b9ee6f97bfce524e3619a1f49f0e'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672309',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 16877058,
#    'login': 'yaroslavNqualisystems',
#    'display_login': 'yaroslavNqualisystems',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yaroslavNqualisystems',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16877058?'},
#   'repo': {'id': 221949883,
#    'name': 'QualiSystems/Shell-Explorer',
#    'url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer'},
#   'payload': {'action': 'closed',
#    'number': 11,
#    'pull_request': {'url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11',
#     'id': 353625870,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUzNjI1ODcw',
#     'html_url': 'https://github.com/QualiSystems/Shell-Explorer/pull/11',
#     'diff_url': 'https://github.com/QualiSystems/Shell-Explorer/pull/11.diff',
#     'patch_url': 'https://github.com/QualiSystems/Shell-Explorer/pull/11.patch',
#     'issue_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/11',
#     'number': 11,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Feature/parse relreases',
#     'user': {'login': 'yaroslavNqualisystems',
#      'id': 16877058,
#      'node_id': 'MDQ6VXNlcjE2ODc3MDU4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/16877058?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/yaroslavNqualisystems',
#      'html_url': 'https://github.com/yaroslavNqualisystems',
#      'followers_url': 'https://api.github.com/users/yaroslavNqualisystems/followers',
#      'following_url': 'https://api.github.com/users/yaroslavNqualisystems/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/yaroslavNqualisystems/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/yaroslavNqualisystems/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/yaroslavNqualisystems/subscriptions',
#      'organizations_url': 'https://api.github.com/users/yaroslavNqualisystems/orgs',
#      'repos_url': 'https://api.github.com/users/yaroslavNqualisystems/repos',
#      'events_url': 'https://api.github.com/users/yaroslavNqualisystems/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/yaroslavNqualisystems/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-16T15:36:45Z',
#     'updated_at': '2019-12-16T15:37:01Z',
#     'closed_at': '2019-12-16T15:37:00Z',
#     'merged_at': '2019-12-16T15:37:00Z',
#     'merge_commit_sha': '1bc1b4cf5033f544401042a85ac4bd6a3d77256c',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11/commits',
#     'review_comments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11/comments',
#     'review_comment_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/11/comments',
#     'statuses_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/statuses/4319f7e7b0d409880a2ddc5268cec3ada0a19259',
#     'head': {'label': 'QualiSystems:feature/parse_relreases',
#      'ref': 'feature/parse_relreases',
#      'sha': '4319f7e7b0d409880a2ddc5268cec3ada0a19259',
#      'user': {'login': 'QualiSystems',
#       'id': 15384617,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1Mzg0NjE3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/15384617?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/QualiSystems',
#       'html_url': 'https://github.com/QualiSystems',
#       'followers_url': 'https://api.github.com/users/QualiSystems/followers',
#       'following_url': 'https://api.github.com/users/QualiSystems/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/QualiSystems/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/QualiSystems/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/QualiSystems/subscriptions',
#       'organizations_url': 'https://api.github.com/users/QualiSystems/orgs',
#       'repos_url': 'https://api.github.com/users/QualiSystems/repos',
#       'events_url': 'https://api.github.com/users/QualiSystems/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/QualiSystems/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 221949883,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjE5NDk4ODM=',
#       'name': 'Shell-Explorer',
#       'full_name': 'QualiSystems/Shell-Explorer',
#       'private': False,
#       'owner': {'login': 'QualiSystems',
#        'id': 15384617,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1Mzg0NjE3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/15384617?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/QualiSystems',
#        'html_url': 'https://github.com/QualiSystems',
#        'followers_url': 'https://api.github.com/users/QualiSystems/followers',
#        'following_url': 'https://api.github.com/users/QualiSystems/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/QualiSystems/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/QualiSystems/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/QualiSystems/subscriptions',
#        'organizations_url': 'https://api.github.com/users/QualiSystems/orgs',
#        'repos_url': 'https://api.github.com/users/QualiSystems/repos',
#        'events_url': 'https://api.github.com/users/QualiSystems/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/QualiSystems/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/QualiSystems/Shell-Explorer',
#       'description': 'Contain scripts and list of explored shells and packages',
#       'fork': False,
#       'url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer',
#       'forks_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/forks',
#       'keys_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/teams',
#       'hooks_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/hooks',
#       'issue_events_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/events',
#       'assignees_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/tags',
#       'blobs_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/languages',
#       'stargazers_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/stargazers',
#       'contributors_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/contributors',
#       'subscribers_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/subscription',
#       'commits_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/merges',
#       'archive_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/downloads',
#       'issues_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/deployments',
#       'created_at': '2019-11-15T15:21:09Z',
#       'updated_at': '2019-11-26T11:38:29Z',
#       'pushed_at': '2019-12-16T15:37:00Z',
#       'git_url': 'git://github.com/QualiSystems/Shell-Explorer.git',
#       'ssh_url': 'git@github.com:QualiSystems/Shell-Explorer.git',
#       'clone_url': 'https://github.com/QualiSystems/Shell-Explorer.git',
#       'svn_url': 'https://github.com/QualiSystems/Shell-Explorer',
#       'homepage': None,
#       'size': 50,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'QualiSystems:dev',
#      'ref': 'dev',
#      'sha': '6a1e550d2624d34e7d8a7140daed7fd1f12cd7de',
#      'user': {'login': 'QualiSystems',
#       'id': 15384617,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1Mzg0NjE3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/15384617?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/QualiSystems',
#       'html_url': 'https://github.com/QualiSystems',
#       'followers_url': 'https://api.github.com/users/QualiSystems/followers',
#       'following_url': 'https://api.github.com/users/QualiSystems/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/QualiSystems/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/QualiSystems/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/QualiSystems/subscriptions',
#       'organizations_url': 'https://api.github.com/users/QualiSystems/orgs',
#       'repos_url': 'https://api.github.com/users/QualiSystems/repos',
#       'events_url': 'https://api.github.com/users/QualiSystems/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/QualiSystems/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 221949883,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjE5NDk4ODM=',
#       'name': 'Shell-Explorer',
#       'full_name': 'QualiSystems/Shell-Explorer',
#       'private': False,
#       'owner': {'login': 'QualiSystems',
#        'id': 15384617,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE1Mzg0NjE3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/15384617?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/QualiSystems',
#        'html_url': 'https://github.com/QualiSystems',
#        'followers_url': 'https://api.github.com/users/QualiSystems/followers',
#        'following_url': 'https://api.github.com/users/QualiSystems/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/QualiSystems/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/QualiSystems/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/QualiSystems/subscriptions',
#        'organizations_url': 'https://api.github.com/users/QualiSystems/orgs',
#        'repos_url': 'https://api.github.com/users/QualiSystems/repos',
#        'events_url': 'https://api.github.com/users/QualiSystems/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/QualiSystems/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/QualiSystems/Shell-Explorer',
#       'description': 'Contain scripts and list of explored shells and packages',
#       'fork': False,
#       'url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer',
#       'forks_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/forks',
#       'keys_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/teams',
#       'hooks_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/hooks',
#       'issue_events_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/events',
#       'assignees_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/tags',
#       'blobs_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/languages',
#       'stargazers_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/stargazers',
#       'contributors_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/contributors',
#       'subscribers_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/subscribers',
#       'subscription_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/subscription',
#       'commits_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/merges',
#       'archive_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/downloads',
#       'issues_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/deployments',
#       'created_at': '2019-11-15T15:21:09Z',
#       'updated_at': '2019-11-26T11:38:29Z',
#       'pushed_at': '2019-12-16T15:37:00Z',
#       'git_url': 'git://github.com/QualiSystems/Shell-Explorer.git',
#       'ssh_url': 'git@github.com:QualiSystems/Shell-Explorer.git',
#       'clone_url': 'https://github.com/QualiSystems/Shell-Explorer.git',
#       'svn_url': 'https://github.com/QualiSystems/Shell-Explorer',
#       'homepage': None,
#       'size': 50,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11'},
#      'html': {'href': 'https://github.com/QualiSystems/Shell-Explorer/pull/11'},
#      'issue': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/11'},
#      'comments': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/issues/11/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/pulls/11/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/QualiSystems/Shell-Explorer/statuses/4319f7e7b0d409880a2ddc5268cec3ada0a19259'}},
#     'author_association': 'COLLABORATOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'yaroslavNqualisystems',
#      'id': 16877058,
#      'node_id': 'MDQ6VXNlcjE2ODc3MDU4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/16877058?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/yaroslavNqualisystems',
#      'html_url': 'https://github.com/yaroslavNqualisystems',
#      'followers_url': 'https://api.github.com/users/yaroslavNqualisystems/followers',
#      'following_url': 'https://api.github.com/users/yaroslavNqualisystems/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/yaroslavNqualisystems/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/yaroslavNqualisystems/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/yaroslavNqualisystems/subscriptions',
#      'organizations_url': 'https://api.github.com/users/yaroslavNqualisystems/orgs',
#      'repos_url': 'https://api.github.com/users/yaroslavNqualisystems/repos',
#      'events_url': 'https://api.github.com/users/yaroslavNqualisystems/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/yaroslavNqualisystems/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 2,
#     'deletions': 1468,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 15384617,
#    'login': 'QualiSystems',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/QualiSystems',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15384617?'}},
#  {'id': '11098672305',
#   'type': 'PushEvent',
#   'actor': {'id': 44290907,
#    'login': 'PawelKunka',
#    'display_login': 'PawelKunka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PawelKunka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44290907?'},
#   'repo': {'id': 227909327,
#    'name': 'kamiljan199/IOP',
#    'url': 'https://api.github.com/repos/kamiljan199/IOP'},
#   'payload': {'push_id': 4402625086,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ParcelRegistration',
#    'head': 'c864ae0d1f80ff0a9a2559226f748d4291cc57a4',
#    'before': 'f6df64d03d66c6178b97adb9fab978db254697df',
#    'commits': [{'sha': 'c864ae0d1f80ff0a9a2559226f748d4291cc57a4',
#      'author': {'email': 'pawelkun@gmail.com', 'name': 'PawelKunka'},
#      'message': 'TODO note added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kamiljan199/IOP/commits/c864ae0d1f80ff0a9a2559226f748d4291cc57a4'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672285',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 118258408,
#    'name': 'wingscms/wings',
#    'url': 'https://api.github.com/repos/wingscms/wings'},
#   'payload': {'push_id': 4402625071,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/gatsby-monorepo',
#    'head': '65e2276581871a4cbbe4f62f65b4e0de6be413db',
#    'before': 'cfc958031214fec50f364560b6e62275774e65a8',
#    'commits': [{'sha': '81f82d7a3c80d9fa35a02e26e657af5ea580c114',
#      'author': {'email': 'busstra.m@gmail.com', 'name': 'Maarten Busstra'},
#      'message': 'chore(release): publish\n\n - @wingscms/crane@0.17.0\n - @wingscms/gatsby-starter-hummingbird@0.2.37\n - @wingscms/hummingbird@0.41.0\n - @wingscms/proxy@0.2.14\n - @wingscms/react@0.25.0',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/wingscms/wings/commits/81f82d7a3c80d9fa35a02e26e657af5ea580c114'},
#     {'sha': '65e2276581871a4cbbe4f62f65b4e0de6be413db',
#      'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'message': 'chore(deps): update gatsby monorepo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wingscms/wings/commits/65e2276581871a4cbbe4f62f65b4e0de6be413db'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 23752907,
#    'login': 'wingscms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wingscms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23752907?'}},
#  {'id': '11098672279',
#   'type': 'PushEvent',
#   'actor': {'id': 22868546,
#    'login': 'javidaslan',
#    'display_login': 'javidaslan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/javidaslan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22868546?'},
#   'repo': {'id': 211623424,
#    'name': 'javidaslan/network-automation',
#    'url': 'https://api.github.com/repos/javidaslan/network-automation'},
#   'payload': {'push_id': 4402625057,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1dbf28bb010544746c4f02ea13c42cf07c768f88',
#    'before': '7c4da672c37fda2c8ba639122bb87436f649d91c',
#    'commits': [{'sha': '1dbf28bb010544746c4f02ea13c42cf07c768f88',
#      'author': {'email': 'j.aslanov94@gmail.com', 'name': 'Javid Aslanov'},
#      'message': 'Create ThreadedConnectHandler.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/javidaslan/network-automation/commits/1dbf28bb010544746c4f02ea13c42cf07c768f88'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672300',
#   'type': 'CreateEvent',
#   'actor': {'id': 5439197,
#    'login': 'julienrat',
#    'display_login': 'julienrat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/julienrat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5439197?'},
#   'repo': {'id': 50240077,
#    'name': 'julienrat/eleduino_screen',
#    'url': 'https://api.github.com/repos/julienrat/eleduino_screen'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'config file for rpi2 to use eleduino screen',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672268',
#   'type': 'PushEvent',
#   'actor': {'id': 13589980,
#    'login': 'thrijith',
#    'display_login': 'thrijith',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thrijith',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13589980?'},
#   'repo': {'id': 21206305,
#    'name': 'laterpay/laterpay-wordpress-plugin',
#    'url': 'https://api.github.com/repos/laterpay/laterpay-wordpress-plugin'},
#   'payload': {'push_id': 4402625066,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/update/contribution-generator-and-block',
#    'head': 'd4cce5af3d063f0eefcc15eb8bc26f596a00e4a5',
#    'before': '4c60d3f5a43113710daf5ee1c443e16932eed1b3',
#    'commits': [{'sha': 'd4cce5af3d063f0eefcc15eb8bc26f596a00e4a5',
#      'author': {'email': 'thrijith13@gmail.com',
#       'name': 'Thrijith Thankachan'},
#      'message': 'Update translations for contribution dialog tilte and description strings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/laterpay/laterpay-wordpress-plugin/commits/d4cce5af3d063f0eefcc15eb8bc26f596a00e4a5'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 1955984,
#    'login': 'laterpay',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/laterpay',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1955984?'}},
#  {'id': '11098672258',
#   'type': 'PushEvent',
#   'actor': {'id': 58179990,
#    'login': 'bazizyacine',
#    'display_login': 'bazizyacine',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bazizyacine',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58179990?'},
#   'repo': {'id': 228337161,
#    'name': 'bazizyacine/java-labs',
#    'url': 'https://api.github.com/repos/bazizyacine/java-labs'},
#   'payload': {'push_id': 4402625049,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'de999afd404a5852493f2ebbcda74d17840ca9a0',
#    'before': 'd5201507d119eafb8a02f6cee394dd423e4c1b96',
#    'commits': [{'sha': 'de999afd404a5852493f2ebbcda74d17840ca9a0',
#      'author': {'email': '58179990+bazizyacine@users.noreply.github.com',
#       'name': 'bazizyacine'},
#      'message': 'test',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bazizyacine/java-labs/commits/de999afd404a5852493f2ebbcda74d17840ca9a0'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672265',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 2476733,
#    'login': 'Graham42',
#    'display_login': 'Graham42',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Graham42',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2476733?'},
#   'repo': {'id': 6093316,
#    'name': 'DefinitelyTyped/DefinitelyTyped',
#    'url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/comments/358301496',
#     'pull_request_review_id': 332656688,
#     'id': 358301496,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1ODMwMTQ5Ng==',
#     'diff_hunk': '@@ -173,10 +173,14 @@ export interface NewmanRunExecutionAssertionError {\n     test: string;\n     message: string;\n     stack: string;\n-}export interface NewmanRunFailure {\n+}\n+export interface NewmanRunFailure {\n     error: NewmanRunExecutionAssertionError;\n     /** The event where the failure occurred */\n     at: string;\n+    source: any;\n+    parent: any;\n+    cursor: any;',
#     'path': 'types/newman/index.d.ts',
#     'position': 12,
#     'original_position': 12,
#     'commit_id': '0b7925b110f67876df67e898fbe2dc592774fb5f',
#     'original_commit_id': '0b7925b110f67876df67e898fbe2dc592774fb5f',
#     'user': {'login': 'Graham42',
#      'id': 2476733,
#      'node_id': 'MDQ6VXNlcjI0NzY3MzM=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/2476733?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Graham42',
#      'html_url': 'https://github.com/Graham42',
#      'followers_url': 'https://api.github.com/users/Graham42/followers',
#      'following_url': 'https://api.github.com/users/Graham42/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Graham42/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Graham42/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Graham42/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Graham42/orgs',
#      'repos_url': 'https://api.github.com/users/Graham42/repos',
#      'events_url': 'https://api.github.com/users/Graham42/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Graham42/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'A guess based on https://github.com/postmanlabs/newman/blob/d984e5d042f131bc43b4f359044f8b772e5b803d/test/unit/run-summary.test.js#L73\r\nand other usage\r\nhttps://github.com/postmanlabs/newman/blob/e08983dad7798531a4f42e3747b3a6d101ac949e/lib/run/summary.js#L238-L241\r\n```suggestion\r\n    cursor: { ref: string } | {};\r\n```',
#     'created_at': '2019-12-16T15:37:00Z',
#     'updated_at': '2019-12-16T15:37:00Z',
#     'html_url': 'https://github.com/DefinitelyTyped/DefinitelyTyped/pull/41033#discussion_r358301496',
#     'pull_request_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/41033',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/comments/358301496'},
#      'html': {'href': 'https://github.com/DefinitelyTyped/DefinitelyTyped/pull/41033#discussion_r358301496'},
#      'pull_request': {'href': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/41033'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/41033',
#     'id': 353128630,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUzMTI4NjMw',
#     'html_url': 'https://github.com/DefinitelyTyped/DefinitelyTyped/pull/41033',
#     'diff_url': 'https://github.com/DefinitelyTyped/DefinitelyTyped/pull/41033.diff',
#     'patch_url': 'https://github.com/DefinitelyTyped/DefinitelyTyped/pull/41033.patch',
#     'issue_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/issues/41033',
#     'number': 41033,
#     'state': 'open',
#     'locked': False,
#     'title': '[newman] Adding missing fields to NewmanRunFailure.',
#     'user': {'login': 'FormerPhysicist',
#      'id': 31143037,
#      'node_id': 'MDQ6VXNlcjMxMTQzMDM3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/31143037?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/FormerPhysicist',
#      'html_url': 'https://github.com/FormerPhysicist',
#      'followers_url': 'https://api.github.com/users/FormerPhysicist/followers',
#      'following_url': 'https://api.github.com/users/FormerPhysicist/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/FormerPhysicist/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/FormerPhysicist/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/FormerPhysicist/subscriptions',
#      'organizations_url': 'https://api.github.com/users/FormerPhysicist/orgs',
#      'repos_url': 'https://api.github.com/users/FormerPhysicist/repos',
#      'events_url': 'https://api.github.com/users/FormerPhysicist/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/FormerPhysicist/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Please fill in this template.\r\n\r\n- [x] Use a meaningful title for the pull request. Include the name of the package modified.\r\n- [x] Test the change in your own code. (Compile and run.)\r\n- [x] Add or edit tests to reflect the change. (Run with `npm test`.)\r\n- [x] Follow the advice from the [readme](https://github.com/DefinitelyTyped/DefinitelyTyped/blob/master/README.md#make-a-pull-request).\r\n- [x] Avoid [common mistakes](https://github.com/DefinitelyTyped/DefinitelyTyped/blob/master/README.md#common-mistakes).\r\n- [x] Run `npm run lint package-name` (or `tsc` if no `tslint.json` is present).\r\n\r\nIf changing an existing definition:\r\n- [x] Provide a URL to documentation or source code which provides context for the suggested changes: \r\n\r\nThere are 3 fields missing from the NewmanRunFailure type: source, parent, cursor.  See link below.  These fields are present from newman 3.1.1 to the present version. Not being familiar with the newman or postman code base, I don't know the shapes of these fields, but I think they should at least be included with a type of 'any'\r\n\r\n[location in code where they add failures](https://github.com/postmanlabs/newman/blob/b2208685bde2152546975a1e07ab21d9726eadb3/lib/run/summary.js#L319) \r\n",
#     'created_at': '2019-12-14T01:31:29Z',
#     'updated_at': '2019-12-16T15:37:00Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '82715fdc3833609aa5ea7a455590374ffefd73c4',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 397523192,
#       'node_id': 'MDU6TGFiZWwzOTc1MjMxOTI=',
#       'url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/labels/Awaiting%20reviewer%20feedback',
#       'name': 'Awaiting reviewer feedback',
#       'color': '0052cc',
#       'default': False,
#       'description': 'This PR is waiting for someone to review its code.'},
#      {'id': 1596194744,
#       'node_id': 'MDU6TGFiZWwxNTk2MTk0NzQ0',
#       'url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/labels/Perf:%20Same',
#       'name': 'Perf: Same',
#       'color': '7CB772',
#       'default': False,
#       'description': 'typescript-bot determined that this PR will not significantly impact compilation performance.'}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/41033/commits',
#     'review_comments_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/41033/comments',
#     'review_comment_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/issues/41033/comments',
#     'statuses_url': 'https://api.github.com/repos/DefinitelyTyped/DefinitelyTyped/statuses/0b7925b110f67876df67e898fbe2dc592774fb5f',
#     'head': {'label': 'FormerPhysicist:newman-update',
#      'ref': 'newman-update',
#      'sha': '0b7925b110f67876df67e898fbe2dc592774fb5f',
#      'user': {'login': 'FormerPhysicist',
#       'id': 31143037,
#       'node_id': 'MDQ6VXNlcjMxMTQzMDM3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/31143037?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/FormerPhysicist',
#       'html_url': 'https://github.com/FormerPhysicist',
#       'followers_url': 'https://api.github.com/users/FormerPhysicist/followers',
#       'following_url': 'https://api.github.com/users/FormerPhysicist/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/FormerPhysicist/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/FormerPhysicist/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/FormerPhysicist/subscriptions',
#       'organizations_url': 'https://api.github.com/users/FormerPhysicist/orgs',
#       'repos_url': 'https://api.github.com/users/FormerPhysicist/repos',
#       'events_url': 'https://api.github.com/users/FormerPhysicist/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/FormerPhysicist/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 227674204,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjc2NzQyMDQ=',
#       'name': 'DefinitelyTyped',
#       'full_name': 'FormerPhysicist/DefinitelyTyped',
#       'private': False,
#       'owner': {'login': 'FormerPhysicist',
#        'id': 31143037,
#        'node_id': 'MDQ6VXNlcjMxMTQzMDM3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/31143037?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/FormerPhysicist',
#        'html_url': 'https://github.com/FormerPhysicist',
#        'followers_url': 'https://api.github.com/users/FormerPhysicist/followers',
#        'following_url': 'https://api.github.com/users/FormerPhysicist/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/FormerPhysicist/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/FormerPhysicist/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/FormerPhysicist/subscriptions',
#        'organizations_url': 'https://api.github.com/users/FormerPhysicist/orgs',
#        'repos_url': 'https://api.github.com/users/FormerPhysicist/repos',
#        'events_url': 'https://api.github.com/users/FormerPhysicist/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/FormerPhysicist/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/FormerPhysicist/DefinitelyTyped',
#       'description': 'The repository for high quality TypeScript type definitions.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped',
#       'forks_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/forks',
#       'keys_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/teams',
#       'hooks_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/events',
#       'assignees_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/tags',
#       'blobs_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/languages',
#       'stargazers_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/subscription',
#       'commits_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/merges',
#       'archive_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/downloads',
#       'issues_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FormerPhysicist/DefinitelyTyped/deployments',
#       'created_at': '2019-12-12T18:45:49Z',
#       'updated_at': '2019-12-12T18:45:53Z',
#       'pushed_at': '2019-12-14T01:19:56Z',
#       'git_url': 'git://github.com/FormerPhysicist/DefinitelyTyped.git',
#       'ssh_url': 'git@github.com:FormerPhysicist/DefinitelyTyped.git',
#       'clone_url': 'https://github.com/FormerPhysicist/DefinitelyTyped.git',
#       'svn_url': 'https://github.com/FormerPhysicist/DefinitelyTyped',
#       'homepage': 'http://definitelytyped.org/',
#       'size': 521414,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'DefinitelyTyped:master',
#      'ref': 'master',
#      'sha': '288692b272b695eda00a47f93339e1e16ee756b1',
#      'user': {'login': 'DefinitelyTyped',
#       'id': 3637556,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM2Mzc1NTY=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/3637556?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DefinitelyTyped',
#       'html_url': 'https://github.com/DefinitelyTyped',
#       'followers_url': 'https://api.github.com/users/DefinitelyTyped/followers',
#       'following_url': 'https://api.github.com/users/DefinitelyTyped/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DefinitelyTyped/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DefinitelyTyped/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DefinitelyTyped/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DefinitelyTyped/orgs',
#       'repos_url': 'https://api.github.com/users/DefinitelyTyped/repos',
#       'events_url': 'https://api.github.com/users/DefinitelyTyped/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DefinitelyTyped/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 6093316,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk2MDkzMzE2',
#       'name': 'DefinitelyTyped',
#       'full_name': 'DefinitelyTyped/DefinitelyTyped',
#       'private': False,
#       'owner': {'login': 'DefinitelyTyped',
#        'id': 3637556,
# ...
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/4502793?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/liferay-continuous-integration',
#      'html_url': 'https://github.com/liferay-continuous-integration',
#      'followers_url': 'https://api.github.com/users/liferay-continuous-integration/followers',
#      'following_url': 'https://api.github.com/users/liferay-continuous-integration/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/liferay-continuous-integration/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/liferay-continuous-integration/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/liferay-continuous-integration/subscriptions',
#      'organizations_url': 'https://api.github.com/users/liferay-continuous-integration/orgs',
#      'repos_url': 'https://api.github.com/users/liferay-continuous-integration/repos',
#      'events_url': 'https://api.github.com/users/liferay-continuous-integration/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/liferay-continuous-integration/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-16T15:37:00Z',
#     'updated_at': '2019-12-16T15:37:00Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'To conserve resources, the PR Tester does not automatically run for every pull.\n\nIf your code changes were already tested in another pull, reference that pull in this pull so the test results can be analyzed.\n\nIf your pull was never tested, comment &quot;ci:test&quot; to run the PR Tester for this pull.'}},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672222',
#   'type': 'CreateEvent',
#   'actor': {'id': 10864294,
#    'login': 'DomHudson',
#    'display_login': 'DomHudson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DomHudson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10864294?'},
#   'repo': {'id': 147229508,
#    'name': 'ThoughtRiver/lmdb-embeddings',
#    'url': 'https://api.github.com/repos/ThoughtRiver/lmdb-embeddings'},
#   'payload': {'ref': 'v0.3.0',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Fast word vectors with little memory usage in Python',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 10865734,
#    'login': 'ThoughtRiver',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ThoughtRiver',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10865734?'}},
#  {'id': '11098672254',
#   'type': 'PushEvent',
#   'actor': {'id': 21128574,
#    'login': 'AkhileshNS',
#    'display_login': 'AkhileshNS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AkhileshNS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21128574?'},
#   'repo': {'id': 200568485,
#    'name': 'AkhileshNS/auto-registrator',
#    'url': 'https://api.github.com/repos/AkhileshNS/auto-registrator'},
#   'payload': {'push_id': 4402625039,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '02036dc0cbc5f4054b401bee1db72ca9fb215ab6',
#    'before': '68d5a5eea928048a7df8f705a6a54ca43166d582',
#    'commits': [{'sha': '02036dc0cbc5f4054b401bee1db72ca9fb215ab6',
#      'author': {'email': 'nsakhilesh02@gmail.com', 'name': 'AkhileshNS'},
#      'message': 'Fixed dependencies',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AkhileshNS/auto-registrator/commits/02036dc0cbc5f4054b401bee1db72ca9fb215ab6'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672240',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1052165,
#    'login': 'zhenbinwu',
#    'display_login': 'zhenbinwu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhenbinwu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1052165?'},
#   'repo': {'id': 139040591,
#    'name': 'susy2015/StopCfg',
#    'url': 'https://api.github.com/repos/susy2015/StopCfg'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/susy2015/StopCfg/issues/55',
#     'repository_url': 'https://api.github.com/repos/susy2015/StopCfg',
#     'labels_url': 'https://api.github.com/repos/susy2015/StopCfg/issues/55/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/susy2015/StopCfg/issues/55/comments',
#     'events_url': 'https://api.github.com/repos/susy2015/StopCfg/issues/55/events',
#     'html_url': 'https://github.com/susy2015/StopCfg/pull/55',
#     'id': 538012500,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzUzMjQ2ODUx',
#     'number': 55,
#     'title': 'Updating post processing cfg for v5 porduction',
#     'user': {'login': 'scarletnorberg',
#      'id': 15896157,
#      'node_id': 'MDQ6VXNlcjE1ODk2MTU3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/15896157?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/scarletnorberg',
#      'html_url': 'https://github.com/scarletnorberg',
#      'followers_url': 'https://api.github.com/users/scarletnorberg/followers',
#      'following_url': 'https://api.github.com/users/scarletnorberg/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/scarletnorberg/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/scarletnorberg/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/scarletnorberg/subscriptions',
#      'organizations_url': 'https://api.github.com/users/scarletnorberg/orgs',
#      'repos_url': 'https://api.github.com/users/scarletnorberg/repos',
#      'events_url': 'https://api.github.com/users/scarletnorberg/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/scarletnorberg/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-15T06:57:34Z',
#     'updated_at': '2019-12-16T15:37:01Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/susy2015/StopCfg/pulls/55',
#      'html_url': 'https://github.com/susy2015/StopCfg/pull/55',
#      'diff_url': 'https://github.com/susy2015/StopCfg/pull/55.diff',
#      'patch_url': 'https://github.com/susy2015/StopCfg/pull/55.patch'},
#     'body': ''},
#    'comment': {'url': 'https://api.github.com/repos/susy2015/StopCfg/issues/comments/566113158',
#     'html_url': 'https://github.com/susy2015/StopCfg/pull/55#issuecomment-566113158',
#     'issue_url': 'https://api.github.com/repos/susy2015/StopCfg/issues/55',
#     'id': 566113158,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2NjExMzE1OA==',
#     'user': {'login': 'zhenbinwu',
#      'id': 1052165,
#      'node_id': 'MDQ6VXNlcjEwNTIxNjU=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1052165?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/zhenbinwu',
#      'html_url': 'https://github.com/zhenbinwu',
#      'followers_url': 'https://api.github.com/users/zhenbinwu/followers',
#      'following_url': 'https://api.github.com/users/zhenbinwu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/zhenbinwu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/zhenbinwu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/zhenbinwu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/zhenbinwu/orgs',
#      'repos_url': 'https://api.github.com/users/zhenbinwu/repos',
#      'events_url': 'https://api.github.com/users/zhenbinwu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/zhenbinwu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-16T15:37:00Z',
#     'updated_at': '2019-12-16T15:37:00Z',
#     'author_association': 'NONE',
#     'body': '@caleb-james-smith There are changes in sampleCollections_201*.cfg. Can you take a look before I merge this PR? '}},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z',
#   'org': {'id': 10456629,
#    'login': 'susy2015',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/susy2015',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10456629?'}},
#  {'id': '11098672212',
#   'type': 'PushEvent',
#   'actor': {'id': 43169999,
#    'login': 'Benedylbert',
#    'display_login': 'Benedylbert',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Benedylbert',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43169999?'},
#   'repo': {'id': 226518361,
#    'name': 'Benedylbert/my-test-website',
#    'url': 'https://api.github.com/repos/Benedylbert/my-test-website'},
#   'payload': {'push_id': 4402625024,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'fee138bb592055b9603e7f0ca1aa99c612a93000',
#    'before': 'd31352e17a9c2bf64f061e482c04991fbb9ba0ad',
#    'commits': [{'sha': 'ac32ffcca7b94423351cd8af76e44859ed903075',
#      'author': {'email': 'konrad.wroblewski@gmail.com', 'name': 'Konrad'},
#      'message': 'Added tools',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Benedylbert/my-test-website/commits/ac32ffcca7b94423351cd8af76e44859ed903075'},
#     {'sha': 'fee138bb592055b9603e7f0ca1aa99c612a93000',
#      'author': {'email': 'konrad.wroblewski@gmail.com', 'name': 'Konrad'},
#      'message': 'New version of website',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Benedylbert/my-test-website/commits/fee138bb592055b9603e7f0ca1aa99c612a93000'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672225',
#   'type': 'PushEvent',
#   'actor': {'id': 1228030,
#    'login': 'harunene',
#    'display_login': 'harunene',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harunene',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1228030?'},
#   'repo': {'id': 228406354,
#    'name': 'harunene/anzuhanacon',
#    'url': 'https://api.github.com/repos/harunene/anzuhanacon'},
#   'payload': {'push_id': 4402625035,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f585f2809f10858a6f83d87ae31fd30a3eb3794c',
#    'before': 'ce02cd725ef00de38d0bbdcbddbe884b38ab41e8',
#    'commits': [{'sha': 'f585f2809f10858a6f83d87ae31fd30a3eb3794c',
#      'author': {'email': 'taskinrits@gmail.com',
#       'name': 'Hwang yonggi (harunene)'},
#      'message': 'Add meta info',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/harunene/anzuhanacon/commits/f585f2809f10858a6f83d87ae31fd30a3eb3794c'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672206',
#   'type': 'CreateEvent',
#   'actor': {'id': 53529309,
#    'login': 'katana2019',
#    'display_login': 'katana2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/katana2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53529309?'},
#   'repo': {'id': 228418239,
#    'name': 'katana2019/secret-board',
#    'url': 'https://api.github.com/repos/katana2019/secret-board'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '秘密の匿名掲示板マスターコード',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-16T15:37:01Z'},
#  {'id': '11098672203',
#   'type': 'IssuesEvent',
#   'actor': {'id': 54450367,
#    'login': 'maneewihok',
#    'display_login': 'maneewihok',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/maneewihok',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54450367?'},
#   'repo': {'id': 228417236,
#    'name': 'maneewihok/labtest1',
#    'url': 'https://api.github.com/repos/maneewihok/labtest1'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/maneewihok/labtest1/issues/2',
#     'repository_url': 'https://api.github.com/repos/maneewihok/labtest1',
#     'labels_url': 'https://api.github.com/repos/maneewihok/labtest1/issues/2/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/maneewihok/labtest1/issues/2/comments',
#     'events_url': 'https://api.github.com/repos/maneewihok/labtest1/issues/2/events',
#     'html_url': 'https://github.com/maneewihok/labtest1/issues/2',
#     'id': 538488112,
#     'node_id': 'MDU6SXNzdWU1Mzg0ODgxMTI=',
#     'number': 2,
#     'title': 'ทำ Entity XX ของระบบย่อย อิอิ',
#     'user': {'login': 'maneewihok',
#      'id': 54450367,
#      'node_id': 'MDQ6VXNlcjU0NDUwMzY3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/54450367?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/maneewihok',
#      'html_url': 'https://github.com/maneewihok',
#      'followers_url': 'https://api.github.com/users/maneewihok/followers',
#      'following_url': 'https://api.github.com/users/maneewihok/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/maneewihok/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/maneewihok/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/maneewihok/subscriptions',
#      'organizations_url': 'https://api.github.com/users/maneewihok/orgs',
#      'repos_url': 'https://api.github.com/users/maneewihok/repos',
#      'events_url': 'https://api.github.com/users/maneewihok/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/maneewihok/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-16T15:37:00Z',
#     'updated_at': '2019-12-16T15:37:00Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'body': ''}},
#   'public': True,
#   'created_at': '2019-12-16T15:37:00Z'},
#  {'id': '11098672196',
#   'type': 'PushEvent',
#   'actor': {'id': 49302804,
#    'login': 'matteohevinwiilog',
#    'display_login': 'matteohevinwiilog',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matteohevinwiilog',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49302804?'},
#   'repo': {'id': 139444283,
#    'name': 'benoitcostewiilog/WiiStock',
#    'url': 'https://api.github.com/repos/benoitcostewiilog/WiiStock'},
#   'payload': {'push_id': 4402625010,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '0d32797bc0d201c20d79cb24a65095dc855bceae',
#    'before': 'cbe97a1656147fba2fc324f8705ae57dee8974ea',
#    'commits': [{'sha': '0d32797bc0d201c20d79cb24a65095dc855bceae',
#      'author': {'email': 'matteo.hevin@wiilog.fr', 'name': 'm.hevin'},
#      'message': 'HOTFIX LITIGE ARRIVAGE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/benoitcostewiilog/WiiStock/commits/0d32797bc0d201c20d79cb24a65095dc855bceae'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:00Z'},
#  {'id': '11098672201',
#   'type': 'PushEvent',
#   'actor': {'id': 49127376,
#    'login': 'IgorKowalczyk',
#    'display_login': 'IgorKowalczyk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IgorKowalczyk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49127376?'},
#   'repo': {'id': 191607114,
#    'name': 'aurolia-css/aurolia-css.github.io',
#    'url': 'https://api.github.com/repos/aurolia-css/aurolia-css.github.io'},
#   'payload': {'push_id': 4402625012,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '291763ed5b1ec4e9d17b0f73feee0507342df9da',
#    'before': 'ed14d5a326f4b228df0c1eef0274e08dd4ef0a70',
#    'commits': [{'sha': '291763ed5b1ec4e9d17b0f73feee0507342df9da',
#      'author': {'email': 'xxmajonezxx@gmail.com', 'name': 'IgorKowalczyk'},
#      'message': '?',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aurolia-css/aurolia-css.github.io/commits/291763ed5b1ec4e9d17b0f73feee0507342df9da'}]},
#   'public': True,
#   'created_at': '2019-12-16T15:37:00Z',
#   'org': {'id': 51529806,
#    'login': 'aurolia-css',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aurolia-css',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51529806?'}}]

# %% [markdown]
# * jason讀出來檔案較容易閱讀資料

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
'''
data1 = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(data1.text)
# Out:
# {'all': [{'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475ca8a99c3f00140fe4d0',
#    'text': 'Loyal, playful, and alert, Manx are considered to be more "doglike" than other cats.',
# ...
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'More than half of the world’s felines don’t respond to catnip.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de7808a0013130015a3ccb0',
#    'type': 'cat',
#    'text': 'The wealthiest cat in the world is named Blackie.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780a00013130015a3ccb1',
#    'type': 'cat',
#    'text': 'A group of kittens is called a Kindle.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780d30013130015a3ccb2',
#    'type': 'cat',
#    'text': 'In October 1983, a cat named "Félicette" became the first cat in space.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780e60013130015a3ccb3',
#    'type': 'cat',
#    'text': 'Cats can be allergic to humans.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5deb725edeb28e00158cd804',
#    'type': 'cat',
#    'text': 'Cats are nuts.',
#    'user': {'_id': '5deb723adeb28e00158cd803',
#     'name': {'first': 'Trip Store', 'last': 'Krabi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df01498e87f9d00157245af',
#    'type': 'cat',
#    'text': 'Cats has 7 souls.',
#    'user': {'_id': '5df0128be87f9d00157245ad',
#     'name': {'first': 'sagiv', 'last': 'netanel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df1f127cf9b010015052b7d',
#    'type': 'cat',
#    'text': 'Arfa.saif92@gmail.com.',
#    'user': {'_id': '5df1f0f4cf9b010015052b7c',
#     'name': {'first': 'Muhammad', 'last': 'Ehsan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df4f0fa1eb1c40015c5b43e',
#    'type': 'cat',
#    'text': 'Ftyftytfytf.',
#    'user': {'_id': '5df0128be87f9d00157245ad',
#     'name': {'first': 'sagiv', 'last': 'netanel'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
data2 = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(data2.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.75},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.98},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H012',
#    'WaterLevel': 0.7},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.23},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.99},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H012',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.61},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H015',
#    'WaterLevel': 0.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H018',
#    'WaterLevel': 124.1},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.85},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H043',
#    'WaterLevel': 23.04},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.32},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.4},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H010',
#    'WaterLevel': 0.19},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.57},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.62},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H026',
#    'WaterLevel': 106.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.45},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.54},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H023',
#    'WaterLevel': 0.03},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H029',
#    'WaterLevel': 175.97},
#   {'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H016',
#    'WaterLevel': 11.27},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.07},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 13.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H027',
#    'WaterLevel': 145.89},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H082',
#    'WaterLevel': 752.39},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H022',
#    'WaterLevel': 0.16},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H054',
#    'WaterLevel': 48.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.06},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': 0.59},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H080',
#    'WaterLevel': 1068.94},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H058',
#    'WaterLevel': 12.13},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.46},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H051',
#    'WaterLevel': 95.66},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.67},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H018',
#    'WaterLevel': 21.23},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.82},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.6},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H047',
#    'WaterLevel': 72.35},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H020',
#    'WaterLevel': 220.79},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1510H086',
#    'WaterLevel': 317.97},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H008',
#    'WaterLevel': 19.39},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.41},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H058',
#    'WaterLevel': 440.47},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H016',
#    'WaterLevel': 97.9},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1550H017',
#    'WaterLevel': 15.74},
#   {'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'StationIdentifier': '1510H075',
#    'WaterLevel': 346.5},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.76},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 622.43},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.68},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H015',
#    'WaterLevel': 50.08},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H054',
#    'WaterLevel': 704.2},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.05},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1430H040',
#    'WaterLevel': 19.29},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1400H009',
#    'WaterLevel': 191.55},
#   {'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'StationIdentifier': '1140H106',
#    'WaterLevel': 49.11},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.19},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1350H001',
#    'WaterLevel': 169.81},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1300H022',
#    'WaterLevel': -1.01},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1340H011',
#    'WaterLevel': 7.38},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H108',
#    'WaterLevel': 12.12},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1140H099',
#    'WaterLevel': 263.49},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.09},
#   {'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1290H002',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
